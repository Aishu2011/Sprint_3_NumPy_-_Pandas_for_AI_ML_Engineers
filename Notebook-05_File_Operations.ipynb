# %% [markdown]
# # Reading & Writing Data

# %%
import pandas as pd
import numpy as np

# %%
students = pd.DataFrame({
    "ID": [101, 102, 103, 104, 105],
    "Name": ["Aishu", "Rahul", "Priya", "John", "Meena"],
    "Age": [22, 23, 21, 24, 22],
    "Department": ["AI", "ML", "DS", "AI", "ML"],
    "Marks": [95, 88, 91, 84, 89]
})

print(students)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# ### 1. CSV Files
#
# CSV (Comma Separated Values) stores tabular data where each value is separated by commas.
#
# It is the most commonly used format in Data Science and Machine Learning.
#
# Example:
#
# An e-commerce company exports its daily sales report as a CSV file.
#
# #### Write CSV

# %%
students.to_csv("students.csv", index=False)

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %% [markdown]
# #### Read CSV

# %%
df = pd.read_csv("students.csv")

print(df)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### AI/ML Usage
#
# Most datasets downloaded from Kaggle are stored as CSV files.

# %% [markdown]
# ### 2. Excel Files
#
# Excel files store data in worksheets with the extensions .xlsx or .xls.
#
# Example:
#
# A company's HR department stores employee records in Excel files.
#
# #### Write Excel

# %%
students.to_excel("students.xlsx", index=False)

print("Excel file created successfully.")
# Out:
# Excel file created successfully.

# %% [markdown]
# #### Read Excel

# %%
df = pd.read_excel("students.xlsx")

print(df)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### AI/ML Usage
#
# Business datasets are often received in Excel format before being cleaned and converted for machine learning.

# %% [markdown]
# ### 3. JSON Files
# JSON (JavaScript Object Notation) stores data as key-value pairs.
#
# It is widely used in APIs and web applications.
#
# Example:
#
# A weather API returns temperature, humidity, and wind speed in JSON format.
#
# #### Write JSON

# %%
students.to_json(
    "students.json",
    orient="records",
    indent=4
)

print("JSON file created.")
# Out:
# JSON file created.

# %% [markdown]
# #### Read JSON

# %%
df = pd.read_json("students.json")

print(df)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### AI/ML Usage
#
# Many REST APIs return JSON data, which is loaded into Pandas for analysis.

# %% [markdown]
# ### 4. Parquet Files
# Parquet is a column-based storage format that is highly compressed and optimized for big data processing.
#
# Example:
#
# Netflix stores large user-viewing datasets in Parquet because it loads faster and uses less storage.
#
# #### Write Parquet

# %%
# !pip install pyarrow

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
# !pip install fastparquet

# %%
students.to_parquet(
    "students.parquet",
    engine="fastparquet",
    index=False
)

print("Parquet file created.")
# Out:
# Parquet file created.

# %% [markdown]
# #### Read Parquet

# %%
df = pd.read_parquet("students.parquet",engine="fastparquet")

print(df)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### AI/ML Usage
#
# Large datasets in Spark and cloud platforms are commonly stored in Parquet format.

# %% [markdown]
# ### 5. Pickle Files
# Pickle stores Python objects in a binary format.
#
# Unlike CSV or Excel, Pickle preserves the original Python object.
#
# Example:
#
# A data scientist saves a cleaned DataFrame to avoid repeating preprocessing every time.
#
# #### Write Pickle

# %%
students.to_pickle("students.pkl")

print("Pickle file created.")
# Out:
# Pickle file created.

# %% [markdown]
# #### Read Pickle

# %%
df = pd.read_pickle("students.pkl")

print(df)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### AI/ML Usage
#
# Pickle is commonly used to save processed datasets and trained machine learning models.

# %% [markdown]
# ### 6. SQL Tables
# SQL databases store data in tables consisting of rows and columns.
#
# Pandas can both read from and write to SQL databases.
#
# Example:
#
# Banks store customer transactions in SQL databases.

# %%
import sqlite3

# %% [markdown]
# #### Create Database Connection

# %%
connection = sqlite3.connect("students.db")

# %% [markdown]
# #### Write DataFrame to SQL Table

# %%
students.to_sql(
    "student_table",
    connection,
    if_exists="replace",
    index=False
)

print("Table created successfully.")
# Out:
# Table created successfully.

# %% [markdown]
# #### Read SQL Table

# %%
df = pd.read_sql(
    "SELECT * FROM student_table",
    connection
)

print(df)
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### Close Connection

# %%
connection.close()

# %% [markdown]
# #### AI/ML Usage
#
# Machine learning projects often retrieve customer, sales, or medical data directly from SQL databases.

# %% [markdown]
# ### 7. Reading Multiple Files
#
# Sometimes data is split across multiple files, and we need to combine them into one DataFrame.
#
# Example:
#
# A supermarket stores one sales CSV file for each month.
#
# January.csv
#
# February.csv
#
# March.csv
#
# The analyst combines them into one dataset.
#
# #### Create Two Sample Files

# %%
sales1 = pd.DataFrame({
    "Product": ["Laptop", "Phone"],
    "Sales": [100, 200]
})

sales2 = pd.DataFrame({
    "Product": ["Tablet", "Watch"],
    "Sales": [150, 120]
})

sales1.to_csv("sales1.csv", index=False)
sales2.to_csv("sales2.csv", index=False)

print(sales1)
print()
print(sales2)
# Out:
#   Product  Sales
# 0  Laptop    100
# 1   Phone    200
#
#   Product  Sales
# 0  Tablet    150
# 1   Watch    120

# %% [markdown]
# ### Read Multiple Files

# %%
df1 = pd.read_csv("sales1.csv")

df2 = pd.read_csv("sales2.csv")

combined = pd.concat([df1, df2], ignore_index=True)

print(combined)
# Out:
#   Product  Sales
# 0  Laptop    100
# 1   Phone    200
# 2  Tablet    150
# 3   Watch    120

# %% [markdown]
# #### AI/ML Usage
#
# Many datasets are split into multiple files due to their size. They are merged before training a model.

# %% [markdown]
# ### 8. File Path Handling
# A file path specifies the location of a file on the computer.
#
# There are two types:
#
# * Relative Path
# * Absolute Path
#
# #### Relative Path
#
# Uses the current working directory.

# %%
df = pd.read_csv("students.csv")
df
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### Absolute Path
# Specifies the complete location.

# %%
df = pd.read_csv(
    r"C:\Users\nithy\OneDrive\Desktop\Stackly\Sprint_3\students.csv"
)
df
# Out:
#     ID   Name  Age Department  Marks
# 0  101  Aishu   22         AI     95
# 1  102  Rahul   23         ML     88
# 2  103  Priya   21         DS     91
# 3  104   John   24         AI     84
# 4  105  Meena   22         ML     89

# %% [markdown]
# #### Finding the Current Working Directory

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\nithy\OneDrive\Desktop\Stackly\Sprint_3

# %% [markdown]
# Example:
#
# A company stores datasets in different folders

# %% [markdown]
# #### AI/ML Usage
# Correct file path handling ensures notebooks and scripts can locate datasets, making projects portable across different systems and collaborators.
